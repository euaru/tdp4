# %% [markdown]
# # Dasar Pemrograman
#
# ## Tugas 4: Visualisasi Data
#
# ### Mekanisme
#
# Anda hanya diwajibkan untuk mengumpulkan file ini saja ke uploader yang disediakan di http://elearning2.uai.ac.id/. Ganti nama file ini saat pengumpulan menjadi tugas4_NIM.ipynb.
#
# Keterlambatan: Pengumpulan tugas yang melebihi tenggat yang telah ditentukan tidak akan diterima. Keterlambatan akan berakibat pada nilai nol untuk tugas ini.
#
# Kolaborasi: Anda diperbolehkan untuk berdiskusi dengan teman Anda, tetapi dilarang keras menyalin kode maupun tulisan dari teman Anda.
#
# ### Petunjuk
#
# Terdapat beberapa pustaka yang Anda akan gunakan dalam mengerjakan tugas ini, yaitu: NumPy, SciPy, matplotlib, dan seaborn.
#
# Anda tidak diperbolehkan mengimpor modul tambahan untuk tugas ini, kecuali dijelaskan sebaliknya. Namun, seharusnya modul yang tersedia sudah cukup untuk memenuhi kebutuhan Anda.
#
# Kebanyakan dari kode yang dibutuhkan untuk menjawab soal-soal ini hanya terdiri dari 1-2 baris saja.

# %% [markdown]
# ### Import

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

plt.style.use('bmh')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aliakbars/uai-dm/master/dataset/menu.csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat          ...           \
# 0                             25        0.0          ...
# 1                             15        0.0          ...
# 2                             42        0.0          ...
# 3                             52        0.0          ...
# 4                             42        0.0          ...
#
#    Carbohydrates  Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0             31                             10              4
# 1             30                             10              4
# 2             29                             10              4
# 3             30                             10              4
# 4             30                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# 1                             17       3       18                          6
# 2                             17       2       14                          8
# 3                             17       2       21                         15
# 4                             17       2       21                          6
#
#    Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                          0                       25                    15
# 1                          0                       25                     8
# 2                          0                       25                    10
# 3                          0                       30                    15
# 4                          0                       25                    10
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Soal 1.1 (1 poin)
#
# Laporkan statistik dari data yang Anda gunakan.

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# std         5.321873                      26.639209    0.429133    87.269257
# min         0.000000                       0.000000    0.000000     0.000000
# 25%         1.000000                       4.750000    0.000000     5.000000
# 50%         5.000000                      24.000000    0.000000    35.000000
# 75%        10.000000                      48.000000    0.000000    65.000000
# max        20.000000                     102.000000    2.500000   575.000000
#
#        Cholesterol (% Daily Value)       Sodium          ...           \
# count                   260.000000   260.000000          ...
# mean                     18.392308   495.750000          ...
# std                      29.091653   577.026323          ...
# min                       0.000000     0.000000          ...
# 25%                       2.000000   107.500000          ...
# 50%                      11.000000   190.000000          ...
# 75%                      21.250000   865.000000          ...
# max                     192.000000  3600.000000          ...
#
#        Carbohydrates  Carbohydrates (% Daily Value)  Dietary Fiber  \
# count     260.000000                     260.000000     260.000000
# mean       47.346154                      15.780769       1.630769
# std        28.252232                       9.419544       1.567717
# min         0.000000                       0.000000       0.000000
# 25%        30.000000                      10.000000       0.000000
# 50%        44.000000                      15.000000       1.000000
# 75%        60.000000                      20.000000       3.000000
# max       141.000000                      47.000000       7.000000
#
#        Dietary Fiber (% Daily Value)      Sugars     Protein  \
# count                     260.000000  260.000000  260.000000
# mean                        6.530769   29.423077   13.338462
# std                         6.307057   28.679797   11.426146
# min                         0.000000    0.000000    0.000000
# 25%                         0.000000    5.750000    4.000000
# 50%                         5.000000   17.500000   12.000000
# 75%                        10.000000   48.000000   19.000000
# max                        28.000000  128.000000   87.000000
#
#        Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# count                 260.000000                 260.000000
# mean                   13.426923                   8.534615
# std                    24.366381                  26.345542
# min                     0.000000                   0.000000
# 25%                     2.000000                   0.000000
# 50%                     8.000000                   0.000000
# 75%                    15.000000                   4.000000
# max                   170.000000                 240.000000
#
#        Calcium (% Daily Value)  Iron (% Daily Value)
# count               260.000000            260.000000
# mean                 20.973077              7.734615
# std                  17.019953              8.723263
# min                   0.000000              0.000000
# 25%                   6.000000              0.000000
# 50%                  20.000000              4.000000
# 75%                  30.000000             15.000000
# max                  70.000000             40.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ### Soal 1.2 (1 poin)
#
# Tunjukkan semua kolom yang ada dalam dataset.

# %%
df.columns.values
# Out:
# array(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'], dtype=object)

# %% [markdown]
# ### Soal 2 (2 poin)
#
# Tampilkan dalam bar plot distribusi dari nilai `Category`.

# %%
sns.countplot(y='Category', data=df)

# %% [markdown]
# ### Soal 3.1 (2 poin)
#
# Gambarkan histogram dari nilai `Calories`.

# %%
sns.distplot(df['Calories'], kde=False)

# %% [markdown]
# ### Soal 3.2 (1 poin)
#
# Anda mungkin akan menemukan bahwa ada pencilan dari nilai `Calories`. Tunjukkan menu yang dimaksud.

# %%
df[df['Calories']>1750]
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat          ...           \
# 82                            101        1.0          ...
#
#     Carbohydrates  Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82            118                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]

# %% [markdown]
# ### Soal 4.1 (2 poin)
#
# Kita ingin mencari tahu angka kebutuhan gizi dari menu yang ada. Untuk itu, gambarkanlah box plot dari:
#
# - Total Fat (% Daily Value)
# - Saturated Fat (% Daily Value)
# - Cholesterol (% Daily Value)
# - Sodium (% Daily Value)
# - Carbohydrates (% Daily Value)
# - Dietary Fiber (% Daily Value)
# - Vitamin A (% Daily Value)
# - Vitamin C (% Daily Value)
# - Calcium (% Daily Value)
# - Iron (% Daily Value)
#
# Gunakan pustaka [seaborn](https://seaborn.pydata.org/generated/seaborn.boxplot.html) untuk ini.

# %%
sns.boxplot(data=df[['Total Fat (% Daily Value)', 'Saturated Fat (% Daily Value)', 'Cholesterol (% Daily Value)',
                    'Sodium (% Daily Value)', 'Carbohydrates (% Daily Value)', 'Dietary Fiber (% Daily Value)',
                    'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)',
                    'Iron (% Daily Value)']], orient='h')

# %% [markdown]
# ### Soal 4.2 (2 poin)
#
# Dari box plot yang telah Anda hasilkan, Anda akan menemukan bahwa beberapa menu memiliki nilai > 100% angka kebutuhan gizi harian. Cari tahu menu-menu tersebut. Anda dapat menggunakan fungsi `.any(axis=1)` untuk membantu menyeleksi datanya.

# %%
df100 = df[(df['Total Fat (% Daily Value)'] > 100) | (df['Saturated Fat (% Daily Value)'] > 100) | (df['Cholesterol (% Daily Value)'] > 100) |
                    (df['Sodium (% Daily Value)'] > 100) | (df['Carbohydrates (% Daily Value)'] > 100) | (df['Dietary Fiber (% Daily Value)'] > 100) |
                    (df['Vitamin A (% Daily Value)'] > 100) | (df['Vitamin C (% Daily Value)'] > 100) | (df['Calcium (% Daily Value)'] > 100) |
                    (df['Iron (% Daily Value)'] > 100)]

df100
# Out:
#                Category                                            Item  \
# 27            Breakfast                 Big Breakfast (Regular Biscuit)
# 28            Breakfast                   Big Breakfast (Large Biscuit)
# 31            Breakfast   Big Breakfast with Hotcakes (Regular Biscuit)
# 32            Breakfast     Big Breakfast with Hotcakes (Large Biscuit)
# 40            Breakfast                           Fruit & Maple Oatmeal
# 41            Breakfast       Fruit & Maple Oatmeal without Brown Sugar
# 82       Chicken & Fish                    Chicken McNuggets (40 piece)
# 84               Salads     Premium Bacon Ranch Salad (without Chicken)
# 86               Salads  Premium Bacon Ranch Salad with Grilled Chicken
# 87               Salads       Premium Southwest Salad (without Chicken)
# 88               Salads     Premium Southwest Salad with Crispy Chicken
# 89               Salads    Premium Southwest Salad with Grilled Chicken
# 101      Snacks & Sides                                    Apple Slices
# 133           Beverages                Minute Maid Orange Juice (Small)
# 134           Beverages               Minute Maid Orange Juice (Medium)
# 135           Beverages                Minute Maid Orange Juice (Large)
# 231        Coffee & Tea                   Frappé Chocolate Chip (Large)
# 253  Smoothies & Shakes            McFlurry with M&M’s Candies (Medium)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 27    9.5 oz (269 g)       740                430       48.0
# 28     10 oz (283 g)       800                470       52.0
# 31   14.8 oz (420 g)      1090                510       56.0
# 32   15.3 oz (434 g)      1150                540       60.0
# 40    9.6 oz (251 g)       290                 35        4.0
# 41    9.6 oz (251 g)       260                 40        4.0
# 82   22.8 oz (646 g)      1880               1060      118.0
# 84    7.9 oz (223 g)       140                 70        7.0
# 86    8.5 oz (241 g)       220                 80        8.0
# 87    8.1 oz (230 g)       140                 40        4.5
# 88   12.3 oz (348 g)       450                190       22.0
# 89   11.8 oz (335 g)       290                 80        8.0
# 101    1.2 oz (34 g)        15                  0        0.0
# 133     12 fl oz cup       150                  0        0.0
# 134     16 fl oz cup       190                  0        0.0
# 135     22 fl oz cup       280                  0        0.0
# 231     22 fl oz cup       760                280       31.0
# 253  16.2 oz (460 g)       930                290       33.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 27                          73           17.0                             87
# 28                          80           18.0                             90
# 31                          87           19.0                             96
# 32                          93           20.0                            100
# 40                           6            1.5                              8
# 41                           6            1.5                              8
# 82                         182           20.0                            101
# 84                          11            3.5                             18
# 86                          13            4.0                             20
# 87                           7            2.0                              9
# 88                          33            4.5                             22
# 89                          13            2.5                             13
# 101                          0            0.0                              0
# 133                          0            0.0                              0
# 134                          0            0.0                              0
# 135                          0            0.0                              0
# 231                         48           20.0                            101
# 253                         50           20.0                            102
#
#      Trans Fat          ...           Carbohydrates  \
# 27         0.0          ...                      51
# 28         0.0          ...                      56
# 31         0.0          ...                     111
# 32         0.0          ...                     116
# 40         0.0          ...                      58
# 41         0.0          ...                      49
# 82         1.0          ...                     118
# 84         0.0          ...                      10
# 86         0.0          ...                       8
# 87         0.0          ...                      20
# 88         0.0          ...                      42
# 89         0.0          ...                      28
# 101        0.0          ...                       4
# 133        0.0          ...                      34
# 134        0.0          ...                      44
# 135        0.0          ...                      65
# 231        1.5          ...                     111
# 253        1.0          ...                     139
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 27                              17              3
# 28                              19              4
# 31                              37              6
# 32                              39              7
# 40                              19              5
# 41                              16              5
# 82                              39              6
# 84                               3              3
# 86                               3              2
# 87                               7              6
# 88                              14              7
# 89                               9              7
# 101                              1              0
# 133                             11              0
# 134                             15              0
# 135                             22              0
# 231                             37              1
# 253                             46              2
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 27                              12       3       28
# 28                              17       3       28
# 31                              23      17       36
# 32                              28      17       36
# 40                              19      32        5
# 41                              22      18        5
# 82                              24       1       87
# 84                              12       4        9
# 86                              10       4       29
# 87                              23       6        6
# 88                              28      12       23
# 89                              28      10       27
# 101                              0       3        0
# 133                              0      30        2
# 134                              0      39        3
# 135                              0      58        4
# 231                              5      99       12
# 253                              7     128       20
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 27                          15                          2
# 28                          15                          2
# 31                          15                          2
# 32                          15                          2
# 40                           2                        130
# 41                           2                        130
# 82                           0                         15
# 84                         170                         30
# 86                         110                         30
# 87                         160                         25
# 88                         170                         30
# 89                         170                         30
# 101                          0                        160
# 133                          0                        130
# 134                          0                        160
# 135                          0                        240
# 231                         20                          0
# 253                         25                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 27                        15                    25
# 28                        15                    30
# 31                        25                    40
# 32                        30                    40
# 40                        10                    10
# 41                         6                    10
# 82                         8                    25
# 84                        15                     6
# 86                        15                     8
# 87                        15                    10
# 88                        15                    15
# 89                        15                    15
# 101                        2                     0
# 133                        2                     0
# 134                        4                     0
# 135                        4                     0
# 231                       35                     6
# 253                       70                    10
#
# [18 rows x 24 columns]

# %% [markdown]
# ### Soal 4.3 (2 poin)
#
# Cari semua menu dengan nilai `Cholesterol (% Daily Value)` > 75.

# %%
df[df['Cholesterol (% Daily Value)'] > 75]
# Out:
#           Category                                           Item  \
# 0        Breakfast                                   Egg McMuffin
# 3        Breakfast                      Sausage McMuffin with Egg
# 5        Breakfast                           Steak & Egg McMuffin
# 6        Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7        Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 12       Breakfast     Sausage Biscuit with Egg (Regular Biscuit)
# 13       Breakfast       Sausage Biscuit with Egg (Large Biscuit)
# 18       Breakfast          Steak & Egg Biscuit (Regular Biscuit)
# 19       Breakfast                 Bacon, Egg & Cheese McGriddles
# 22       Breakfast               Sausage, Egg & Cheese McGriddles
# 24       Breakfast                      Bacon, Egg & Cheese Bagel
# 26       Breakfast                      Steak, Egg & Cheese Bagel
# 27       Breakfast                Big Breakfast (Regular Biscuit)
# 28       Breakfast                  Big Breakfast (Large Biscuit)
# 31       Breakfast  Big Breakfast with Hotcakes (Regular Biscuit)
# 32       Breakfast    Big Breakfast with Hotcakes (Large Biscuit)
# 82  Chicken & Fish                   Chicken McNuggets (40 piece)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 0    4.8 oz (136 g)       300                120       13.0
# 3    5.7 oz (161 g)       450                250       28.0
# 5    6.5 oz (185 g)       430                210       23.0
# 6    5.3 oz (150 g)       460                230       26.0
# 7    5.8 oz (164 g)       520                270       30.0
# 12   5.7 oz (163 g)       510                290       33.0
# 13   6.2 oz (177 g)       570                330       37.0
# 18   7.1 oz (201 g)       540                290       32.0
# 19   6.1 oz (174 g)       460                190       21.0
# 22   7.1 oz (201 g)       550                280       31.0
# 24   6.9 oz (197 g)       620                280       31.0
# 26   8.5 oz (241 g)       670                310       35.0
# 27   9.5 oz (269 g)       740                430       48.0
# 28    10 oz (283 g)       800                470       52.0
# 31  14.8 oz (420 g)      1090                510       56.0
# 32  15.3 oz (434 g)      1150                540       60.0
# 82  22.8 oz (646 g)      1880               1060      118.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                          20            5.0                             25
# 3                          43           10.0                             52
# 5                          36            9.0                             46
# 6                          40           13.0                             65
# 7                          47           14.0                             68
# 12                         50           14.0                             71
# 13                         57           15.0                             74
# 18                         49           16.0                             78
# 19                         32            9.0                             44
# 22                         48           12.0                             61
# 24                         48           11.0                             56
# 26                         53           13.0                             63
# 27                         73           17.0                             87
# 28                         80           18.0                             90
# 31                         87           19.0                             96
# 32                         93           20.0                            100
# 82                        182           20.0                            101
#
#     Trans Fat          ...           Carbohydrates  \
# 0         0.0          ...                      31
# 3         0.0          ...                      30
# 5         1.0          ...                      31
# 6         0.0          ...                      38
# 7         0.0          ...                      43
# 12        0.0          ...                      36
# 13        0.0          ...                      42
# 18        1.0          ...                      38
# 19        0.0          ...                      48
# 22        0.0          ...                      48
# 24        0.5          ...                      57
# 26        1.5          ...                      56
# 27        0.0          ...                      51
# 28        0.0          ...                      56
# 31        0.0          ...                     111
# 32        0.0          ...                     116
# 82        1.0          ...                     118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                              10              4
# 3                              10              4
# 5                              10              4
# 6                              13              2
# 7                              14              3
# 12                             12              2
# 13                             14              3
# 18                             13              2
# 19                             16              2
# 22                             16              2
# 24                             19              3
# 26                             19              3
# 27                             17              3
# 28                             19              4
# 31                             37              6
# 32                             39              7
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                              17       3       17                         10
# 3                              17       2       21                         15
# 5                              18       3       26                         15
# 6                               7       3       19                         10
# 7                              12       4       19                         15
# 12                              6       2       18                          6
# 13                             11       3       18                         10
# 18                              8       3       25                         10
# 19                              9      15       19                         10
# 22                              9      15       20                         10
# 24                             11       7       30                         20
# 26                             12       7       33                         20
# 27                             12       3       28                         15
# 28                             17       3       28                         15
# 31                             23      17       36                         15
# 32                             28      17       36                         15
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 0                           0                       25                    15
# 3                           0                       30                    15
# 5                           2                       30                    20
# 6                           8                       15                    15
# 7                           8                       20                    20
# 12                          0                       10                    20
# 13                          0                       10                    20
# 18                          2                       20                    25
# 19                         10                       20                    15
# 22                          0                       20                    15
# 24                         15                       20                    20
# 26                          4                       25                    25
# 27                          2                       15                    25
# 28                          2                       15                    30
# 31                          2                       25                    40
# 32                          2                       30                    40
# 82                         15                        8                    25
#
# [17 rows x 24 columns]

# %% [markdown]
# ### Soal 5.1 (2 poin)
#
# Tunjukkan nilai korelasi dari `Total Fat` dan `Cholesterol`.

# %%
df['Total Fat'].corr(df['Cholesterol'])
# Out:
# 0.68054736766732471

# %% [markdown]
# ### Soal 5.2 (2 poin)
#
# Gambarkan scatter plot dan garis regresi dari `Total Fat` dan `Cholesterol`. Anda dapat menggunakan fungsi `lmplot()` dari seaborn.

# %%
sns.lmplot(x='Total Fat', y='Cholesterol', data=df)

# %% [markdown]
# ### Soal 6.1 (2 poin)
#
# Menu dengan kategori apa yang memiliki nilai kalori paling besar? Gambarkan box plot untuk `Calories` dengan membaginya berdasarkan `Category`.

# %%
sns.boxplot(x='Calories', y='Category', data=df)

# %% [markdown]
# ### Soal 6.2 (2 poin)
#
# Gambarkan kembali box plot, tapi kali ini untuk `Cholesterol` dengan membaginya berdasarkan `Category`.

# %%
sns.boxplot(x='Cholesterol', y='Category', data=df)

# %% [markdown]
# ### Soal 6.3 (4 poin)
#
# Bagaimana persebaran nilai `Calories` dan `Cholesterol`? Gambarkan contour plot beserta scatter plot-nya. Silakan merujuk ke [notebook ini](http://nbviewer.jupyter.org/github/aliakbars/uai-python/blob/master/scripts/week9/visualisation.ipynb).

# %%
from scipy.stats import multivariate_normal

c = np.linspace(df['Calories'].min() - 1, df['Calories'].max() + 1, 500)
l = np.linspace(df['Cholesterol'].min() - 1, df['Cholesterol'].max() + 1, 500)

x1, x2 = np.meshgrid(c, l)
rv = multivariate_normal([df['Calories'].mean(), df['Cholesterol'].mean()], np.cov(np.array([df['Calories'], df['Cholesterol']])))

pos = np.empty(x1.shape + (2,))
pos[:, :, 0] = x1
pos[:, :, 1] = x2

fig, ax = plt.subplots(figsize=(15,7))
ax.contourf(x1, x2, rv.pdf(pos), cmap='viridis')
ax.scatter(df['Calories'], df['Cholesterol'], c='w')
ax.set_xlim([df['Calories'].min(), df['Calories'].max()])
ax.set_ylim([df['Cholesterol'].min(), df['Cholesterol'].max()])
ax.set_xlabel('Calories')
ax.set_ylabel('Cholesterol')
plt.show()

# %% [markdown]
# ### Soal 7.1 (2 poin)
#
# Hitung nilai korelasi dari `Calories`, `Carbohydrates`, `Sugars`, dan `Protein`.

# %%
corr = df[['Calories', 'Carbohydrates', 'Sugars', 'Protein']].corr()
corr
# Out:
#                Calories  Carbohydrates    Sugars   Protein
# Calories       1.000000       0.781539  0.259598  0.787847
# Carbohydrates  0.781539       1.000000  0.762362  0.352122
# Sugars         0.259598       0.762362  1.000000 -0.179940
# Protein        0.787847       0.352122 -0.179940  1.000000

# %% [markdown]
# ### Soal 7.2 (3 poin)
#
# Gambarkan heatmap dari korelasi yang Anda hitung di atas. Pastikan Anda menganotasi heatmap tersebut. Silakan rujuk dokumentasi [seaborn](https://seaborn.pydata.org/generated/seaborn.heatmap.html).

# %%
sns.heatmap(corr)
